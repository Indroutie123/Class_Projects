# %% [markdown]
# # New Section

# %%
# !git clone https://github.com/YOUR_Indroutie123/Class_Projects.git
# Out:
# Cloning into 'Class_Projects'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv")

# %%
df.shape
# Out:
# (212331, 15)

# %%
 plt.title('Comparison of Average Scores')
# Out:
# Text(0.5, 1.0, 'Comparison of Average Scores')

# %%
plt.ylabel('average score')
# Out:
# Text(0, 0.5, 'average score')

# %%
plt.show()

# %%
df.sample(5)
# Out:
#       School DBN                                        School Name  \
# 6103      10X118                        J.H.S. 118 William W. Niles
# 16071     29Q272  George Washington Carver High School for the S...
# 18443     84M330       Girls Preparatory Charter School of New York
# 68175     09X252                        Mott Hall Bronx High School
# 14272     25Q460                               Flushing High School
#
#                           School Level                 Regents Exam  Year  \
# 6103   Junior High-Intermediate-Middle  U.S. History and Government  2017
# 16071                      High school  U.S. History and Government  2017
# 18443                              K-8          Common Core Algebra  2016
# 68175                      High school          Common Core English  2015
# 14272                      High school           Living Environment  2016
#
#        Total Tested Mean Score Number Scoring Below 65  \
# ...

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
queens_df=df[df['School DBN'].str.contains('E')]
#filter for schools with E in the School DBN

# %%
 plt.bar(['Chosen School', 'Comparison Group'], [chosen_school_mean, comparison_group_mean])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-4bb0c09616c6> in <cell line: 0>()
# ----> 1 plt.bar(['Chosen School', 'Comparison Group'], [chosen_school_mean, comparison_group_mean])
#
# NameError: name 'chosen_school_mean' is not defined

# %%
   "Category": ["Selected School", "Overall", "Borough"],
# Out:
#   File "<ipython-input-59-5b74f566cb69>", line 1
#     "Category": ["Selected School", "Overall", "Borough"],
#     ^
# SyntaxError: illegal target for annotation

# %%
plt.xlabel("Mean Score - Algebra I (Common Core)")
# Out:
# Text(0.5, 0, 'Mean Score - Algebra I (Common Core)')

# %%
plt.figure(figsize=(10, 6))

# %%
sns.histplot(borough_data['Mean Score - Algebra I (Common Core)'],
# Out:
#   File "<ipython-input-62-1ab43eadc519>", line 1
#     sns.histplot(borough_data['Mean Score - Algebra I (Common Core)'],
#                                                                        ^
# SyntaxError: incomplete input

# %%
df.(True, color='blue', label=f"{borough} Schools")
# Out:
#   File "<ipython-input-64-1d0014dc7f3e>", line 1
#     df.(True, color='blue', label=f"{borough} Schools")
#        ^
# SyntaxError: invalid syntax

# %%
sns.histplot(schooldata['Mean Score - Algebra I (Common Core)'],)
# Out:
#   File "<ipython-input-65-dd80372654d3>", line 1
#     sns.histplot(schooldata['Mean Score - Algebra I (Common Core)'],
#                                                                      ^
# SyntaxError: incomplete input

# %%
plt.title(f"Comparison of Algebra I Scores: {chosen_school} vs {borough} Schools")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-d8bfeffe361d> in <cell line: 0>()
# ----> 1 plt.title(f"Comparison of Algebra I Scores: {chosen_school} vs {borough} Schools")
#
# NameError: name 'chosen_school' is not defined

# %%
plt.legend()
# Out:
# <ipython-input-67-a140b03f3a4c>:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.xlabel("Mean Score - Algebra I (Common Core)")
# Out:
# Text(0.5, 0, 'Mean Score - Algebra I (Common Core)')

# %%
df.hist(column='Mean Score - Algebra I (Common Core)', kde=True, color='orange', label=f"epic hight school")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-f2d21807287d> in <cell line: 0>()
# ----> 1 df.hist(column='Mean Score - Algebra I (Common Core)', kde=True, color='orange', label=f"epic hight school")
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     249     """
#     250     plot_backend = _get_plot_backend(backend)
# --> 251     return plot_backend.hist_frame(
#     252         data,
#     253         column=column,
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
# ...

# %%
df.hist(column='Mean Score - Algebra I (Common Core)', kde=True, color='orange', label=f"{P.S. 034 Franklin D. Roosevelt}")
# Out:
#   File "<ipython-input-111-c17fe8333565>", line 1
#     df.hist(column='Mean Score - Algebra I (Common Core)', kde=True, color='orange', label=f"{P.S. 034 Franklin D. Roosevelt}")
#           ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
print(f"Mean Algebra I Score for schools in {queens}: {borough_mean:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-0c561c517674> in <cell line: 0>()
# ----> 1 print(f"Mean Algebra I Score for schools in {queens}: {borough_mean:.2f}")
#
# NameError: name 'queens' is not defined

# %%
print(f"\nDescriptive Statistics:")
# Out:
# Descriptive Statistics:

# %%
df.hist(column='Mean Score', kde=True, color='red', label='queens Schools')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-90235e48bc2d> in <cell line: 0>()
# ----> 1 df.hist(column='Mean Score', kde=True, color='red', label='queens Schools')
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     249     """
#     250     plot_backend = _get_plot_backend(backend)
# --> 251     return plot_backend.hist_frame(
#     252         data,
#     253         column=column,
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     547
#     548     if naxes == 0:
# --> 549         raise ValueError(
# ...

# %%
plt.figure(figsize=(10, 6))

# %%
df.hist(column='Mean Score - Algebra I (Common Core)', kde=True, color='red', label='queens Schools')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-ba0fcc35cdf7> in <cell line: 0>()
# ----> 1 df.hist(column='Mean Score - Algebra I (Common Core)', kde=True, color='red', label='queens Schools')
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     249     """
#     250     plot_backend = _get_plot_backend(backend)
# --> 251     return plot_backend.hist_frame(
#     252         data,
#     253         column=column,
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     539         if not isinstance(column, (list, np.ndarray, ABCIndex)):
# ...

# %%
print(df.columns)
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')
